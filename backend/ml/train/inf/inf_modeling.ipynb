# %% [markdown]
# This is the beginning of my vscode notebook for infield modeling

# %%
import pandas as pd
import numpy as np

csv_path = '/Users/ryankolodziejczyk/Documents/AI Baseball Recruitment/code/backend/data/hitters/inf_data_from_final.csv'
inf_data_all = pd.read_csv(csv_path)

inf_data_all
# Out:
#       height  weight  sixty_time  exit_velo_max  exit_velo_avg  distance_max  \
# 0       73.0   180.0        7.41           89.3           81.8         320.0
# 1       73.0   200.0        7.59           86.7           80.8         312.0
# 2       67.0   143.0        7.43           85.7           78.3         306.0
# 3       71.0   200.0        7.08           90.4           78.8         264.0
# 4       71.0   175.0        7.72           86.8           78.0         269.0
# ...      ...     ...         ...            ...            ...           ...
# 9116    75.0   195.0        7.52           91.1           85.0         321.0
# 9117    70.0   155.0        7.64           88.5           83.3         283.0
# 9118    70.0   183.0        7.61           89.7           83.0         304.0
# 9119    74.0   195.0        7.50           88.6           83.6         328.0
# 9120    72.0   150.0        7.02           80.2           76.5         296.0
#
# ...
